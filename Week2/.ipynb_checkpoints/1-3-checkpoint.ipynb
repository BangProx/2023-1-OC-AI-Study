# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
penguin_df = sns.load_dataset("penguins")

# %%
title = "Body Mass vs Bill Length"
x = penguin_df['body_mass_g']
y = penguin_df['bill_length_mm']

# %%
plt.scatter(x,y)
plt.show()
