# %%
import matplotlib.pyplot as plt
cars=['AUDI', 'BMW', 'FORD', 'TESLA', 'JAGUAR']
data=[23, 29, 41, 12, 17]
explode = [0,0,0.2,0,0]

# %%
plt.pie(data, labels = cars, autopct = '%.1f%%',explode = explode, shadow = True)
plt.show()
