# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x1 = [0, 1, 2, 3, 4, 5]
y1 = [123, 1, 59, 40, 10, 100]
title = "Shape Like W"

# %%
penguin_df = sns.load_dataset("penguins")
title2 = "Body Mass vs Bill Length"
x2 = penguin_df['body_mass_g']
y2 = penguin_df['bill_length_mm']

# %%
plt.figure(figsize = (12,5))
plt.subplot(1, 3, 1)               
plt.plot(x1,y1)
plt.subplot(1,3,2)
plt.bar(x1,y1)
plt.subplot(1,3,3)
plt.scatter(x1,y1)
plt.show()
